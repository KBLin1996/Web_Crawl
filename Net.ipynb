# %%
# https://www.gap.tw/category/9.html#top

# %%
import os

os.makedirs('./Net/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
driver = webdriver.Chrome(chrome_options=chrome_options)
URL = "https://www.net-fashion.net/category/38"

driver.get(URL)
pageSource = driver.page_source
soup = BeautifulSoup(pageSource, "lxml")

img_ul = soup.find_all('div', class_='main_scontent')

for ul in img_ul:
    imgs = ul.find_all('img')

    for img in imgs:
        url = img["src"]
        #url = "https:/" + url
        print(url)
        
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Net/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://net.wimg.tw/files/1/products/240389_400_005E781B0E799BD.jpg?v=18129
# Saved 240389_400_005E781B0E799BD.jpg?v=18129
# https://net.wimg.tw/files/1/products/240389_color_000E99B9CE889B2.jpg?v=18129
# Saved 240389_color_000E99B9CE889B2.jpg?v=18129
# https://net.wimg.tw/files/1/products/240389_color_005E781B0E799BD.jpg?v=18129
# Saved 240389_color_005E781B0E799BD.jpg?v=18129
# https://net.wimg.tw/files/1/products/240389_color_026E99D92E799BD.jpg?v=18129
# Saved 240389_color_026E99D92E799BD.jpg?v=18129
# https://net.wimg.tw/files/1/products/241348_400_900E9BB91E889B2.jpg?v=18129
# Saved 241348_400_900E9BB91E889B2.jpg?v=18129
# https://net.wimg.tw/files/1/products/239949_400_324E7B485E889B2.jpg?v=18129
# Saved 239949_400_324E7B485E889B2.jpg?v=18129
# https://net.wimg.tw/files/1/products/239949_color_020E6B7BAE9BABBE781B0.jpg?v=18129
# Saved 239949_color_020E6B7BAE9BABBE781B0.jpg?v=18129
# https://net.wimg.tw/files/1/products/239949_color_324E7B485E889B2.jpg?v=18129
# ...

# %%
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

for i in range(2, 5):
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--disable-gpu')
    driver = webdriver.Chrome(chrome_options=chrome_options)
    URL = "https://www.net-fashion.net/category/38"
    URL = URL + '/' + str(i)

    driver.get(URL)
    pageSource = driver.page_source
    soup = BeautifulSoup(pageSource, "lxml")
    img_ul = soup.find_all('div', class_='main_scontent')

    for ul in img_ul:
        imgs = ul.find_all('img')

        for img in imgs:
            url = img["src"]
            #url = "https:/" + url
            print(url)
        
            r = requests.get(url, stream=True)
            image_name = url.split('/')[-1]
            with open('./Net/%s' % image_name, 'wb') as f:
                for chunk in r.iter_content(chunk_size=1024):
                    f.write(chunk)
            print('Saved %s' % image_name)
# Out:
# https://net.wimg.tw/files/1/products/233799_400_022E9BABBE781B0.jpg?v=18129
# Saved 233799_400_022E9BABBE781B0.jpg?v=18129
# https://net.wimg.tw/files/1/products/233799_color_001E99BAAE799BD.jpg?v=18129
# Saved 233799_color_001E99BAAE799BD.jpg?v=18129
# https://net.wimg.tw/files/1/products/233799_color_022E9BABBE781B0.jpg?v=18129
# Saved 233799_color_022E9BABBE781B0.jpg?v=18129
# https://net.wimg.tw/files/1/products/233799_color_324E7B485E889B2.jpg?v=18129
# Saved 233799_color_324E7B485E889B2.jpg?v=18129
# https://net.wimg.tw/files/1/products/233799_color_711E4B888E99D92.jpg?v=18129
# Saved 233799_color_711E4B888E99D92.jpg?v=18129
# https://net.wimg.tw/files/1/products/240371_400_712E6B0B4E8978D.jpg?v=18129
# Saved 240371_400_712E6B0B4E8978D.jpg?v=18129
# https://net.wimg.tw/files/1/products/240371_color_712E6B0B4E8978D.jpg?v=18129
# Saved 240371_color_712E6B0B4E8978D.jpg?v=18129
# https://net.wimg.tw/files/1/products/240371_color_719E6B7B1E8978D.jpg?v=18129
# ...
