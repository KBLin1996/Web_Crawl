# %%
# https://kith.com/collections/apparel/tee

# %%
import os
os.makedirs('./Kith T-shirt/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re

URL = "https://kith.com/collections/apparel/tee"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='filterlayout')
#print(img_ul)

for ul in img_ul:
    imgs = ul.find_all('img')
    #print(imgs)
    
    for img in imgs:
        url = img["src"]
        url = "http:" + url
        print(url)
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Kith T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# http://cdn.shopify.com/s/files/1/0094/2252/products/MBSS18-302-3_600x.progressive.jpg?v=1524597519
# Saved MBSS18-302-3_600x.progressive.jpg?v=1524597519
# http://cdn.shopify.com/s/files/1/0094/2252/products/MBSS18-302-4_600x.progressive.jpg?v=1524597519
# Saved MBSS18-302-4_600x.progressive.jpg?v=1524597519
# http://cdn.shopify.com/s/files/1/0094/2252/products/ALDS00531-2_600x.progressive.jpg?v=1520981035
# Saved ALDS00531-2_600x.progressive.jpg?v=1520981035
# http://cdn.shopify.com/s/files/1/0094/2252/products/ALDS00531-4_600x.progressive.jpg?v=1520981035
# Saved ALDS00531-4_600x.progressive.jpg?v=1520981035
# http://cdn.shopify.com/s/files/1/0094/2252/products/ALDS00531-8_600x.progressive.jpg?v=1520981153
# Saved ALDS00531-8_600x.progressive.jpg?v=1520981153
# http://cdn.shopify.com/s/files/1/0094/2252/products/ALDS00531-9_600x.progressive.jpg?v=1520981153
# Saved ALDS00531-9_600x.progressive.jpg?v=1520981153
# ...
