# %%
# http://www2.hm.com/zh_asia3/men/shop-by-product/t-shirts-and-tanks.html?product-type=men_tshirtstanks_shortsleeve%2Cmen_tshirtstanks_shortsleeve&sort=stock&offset=0&page-size=270

# %%
import os

os.makedirs('./H&M Short-Sleeve/', exist_ok=True)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re
import shutil

URL = "http://www2.hm.com/zh_asia3/men/shop-by-product/t-shirts-and-tanks.html?product-type=men_tshirtstanks_shortsleeve%2Cmen_tshirtstanks_shortsleeve&sort=stock&offset=0&page-size=270"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='productlisting parbase section')
i=0

for ul in img_ul:
    imgs = ul.find_all('img')

    for img in imgs:
        
        url = img["src"]
                
        b = 'https:'
        url = b + url
        print(url)
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        
        image_name = image_name + str(i)
        i += 1
        with open('./H&M Short-Sleeve/%s' % image_name, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
        f.close()
        del r
# Out:
# https://lp2.hm.com/hmgoepprod?set=source[/7d/d1/7dd18fcb273e946daa1eb8321d2e35292cf9ed5f.jpg],origin[dam],category[men_tshirtstanks_shortsleeve],type[DESCRIPTIVESTILLLIFE],hmver[1]&call=url[file:/product/main]
# https://lp2.hm.com/hmgoepprod?set=source[/01/ee/01ee24c576e399c4ff5c1a63264dd870b1f88ce4.jpg],origin[dam],category[men_tshirtstanks_shortsleeve],type[LOOKBOOK],hmver[1]&call=url[file:/product/main]
# https://lp2.hm.com/hmgoepprod?set=source[/cd/51/cd51a54f44548cac733f4729b67ed509c7792bdc.jpg],origin[dam],category[men_tshirtstanks_shortsleeve],type[LOOKBOOK],hmver[1]&call=url[file:/product/main]
# https://lp2.hm.com/hmgoepprod?set=source[/56/3a/563aa25055ede0c95a7037fee2976ccb4d29739b.jpg],origin[dam],category[men_tshirtstanks_shortsleeve],type[LOOKBOOK],hmver[1]&call=url[file:/product/main]
# ...
