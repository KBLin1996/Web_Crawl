# %%
# https://www.hugoboss.com/boss-men-t-shirts/#load-more-productsearch=180

# %%
import os

os.makedirs('./Boss T-shirt/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re
import time
from selenium import webdriver
from urllib import request                
from bs4 import BeautifulSoup             
from urllib.parse import urlparse         
from urllib.request import urlopen

driver = webdriver.Chrome()
driver.get('https://www.hugoboss.com/boss-men-t-shirts/#load-more-productsearch=180')  
ps = driver.page_source 
soup = BeautifulSoup(ps, "lxml")
   
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='search-result')
#print(img_ul)

i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    #print(imgs)

    for img in imgs:
        url = img["src"]
        if(url[0] != 'h'):
            url = img["data-src"]
        print(url)
        sleep(2)
        
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        image_name = image_name + str(i)
        i += 1
        with open('./Boss T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://images.hugoboss.com/is/image/boss/hbeu50384351_101_21?$large$&wid=270
# Saved hbeu50384351_101_21?$large$&wid=2700
# https://images.hugoboss.com/is/image/boss/hbeu50389098_001_21?$large$&wid=270
# Saved hbeu50389098_001_21?$large$&wid=2701
# https://images.hugoboss.com/is/image/boss/hbeu50369155_059_21?$large$&wid=270
# Saved hbeu50369155_059_21?$large$&wid=2702
# https://images.hugoboss.com/is/image/boss/hbeu50240164_410_21?$large$&wid=270
# Saved hbeu50240164_410_21?$large$&wid=2703
# https://images.hugoboss.com/is/image/boss/hbeu50271056_410_21?$large$&wid=270
# Saved hbeu50271056_410_21?$large$&wid=2704
# https://images.hugoboss.com/is/image/boss/hbeu50245195_001_21?$large$&wid=270
# Saved hbeu50245195_001_21?$large$&wid=2705
# https://images.hugoboss.com/is/image/boss/hbeu50369135_059_21?$large$&wid=270
# Saved hbeu50369135_059_21?$large$&wid=2706
# https://images.hugoboss.com/is/image/boss/hbeu50333772_610_21?$large$&wid=270
# Saved hbeu50333772_610_21?$large$&wid=2707
# ...

# %%
import os

os.makedirs('./Boss Suit/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re
import time

URL = "https://www.hugoboss.com/boss-men-suits/#load-more-productsearch=24"
   
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='search-result')
#print(img_ul)

i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    #print(imgs)

    for img in imgs:
        url = img["src"]
        if(url[0] != 'h'):
            url = img["data-src"]
        print(url)
        
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        image_name = image_name + str(i)
        i += 1
        with open('./Boss Suit/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=4096):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://images.hugoboss.com/is/image/boss/hbeu50384796_458_21?$large$&wid=270
# Saved hbeu50384796_458_21?$large$&wid=2700
# https://images.hugoboss.com/is/image/boss/hbeu50379905_409_21?$large$&wid=270
# Saved hbeu50379905_409_21?$large$&wid=2701
# https://images.hugoboss.com/is/image/boss/hbeu50255636_001_21?$large$&wid=270
# Saved hbeu50255636_001_21?$large$&wid=2702
# https://images.hugoboss.com/is/image/boss/hbeu50251631_001_21?$large$&wid=270
# Saved hbeu50251631_001_21?$large$&wid=2703
# https://images.hugoboss.com/is/image/boss/hbeu50384402_001_21?$large$&wid=270
# Saved hbeu50384402_001_21?$large$&wid=2704
# https://images.hugoboss.com/is/image/boss/hbeu50384303_473_21?$large$&wid=270
# Saved hbeu50384303_473_21?$large$&wid=2705
# https://images.hugoboss.com/is/image/boss/hbeu50309476_001_21?$large$&wid=270
# Saved hbeu50309476_001_21?$large$&wid=2706
# https://images.hugoboss.com/is/image/boss/hbeu50380060_401_21?$large$&wid=270
# Saved hbeu50380060_401_21?$large$&wid=2707
# ...

# %%
import os

os.makedirs('./Boss Shirts/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re
import time

URL = "https://www.hugoboss.com/boss-men-shirts/#load-more-productsearch=156"
   
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='search-result')
#print(img_ul)

i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    #print(imgs)

    for img in imgs:
        url = img["src"]
        if(url[0] != 'h'):
            url = img["data-src"]
        print(url)
        
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        image_name = image_name + str(i)
        i += 1
        with open('./Boss Shirts/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=4096):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://images.hugoboss.com/is/image/boss/hbeu50260064_410_21?$large$&wid=270
# Saved hbeu50260064_410_21?$large$&wid=2700
# https://images.hugoboss.com/is/image/boss/hbeu50260064_100_21?$large$&wid=270
# Saved hbeu50260064_100_21?$large$&wid=2701
# https://images.hugoboss.com/is/image/boss/hbeu50260064_450_21?$large$&wid=270
# Saved hbeu50260064_450_21?$large$&wid=2702
# https://images.hugoboss.com/is/image/boss/hbeu50327693_100_21?$large$&wid=270
# Saved hbeu50327693_100_21?$large$&wid=2703
# https://images.hugoboss.com/is/image/boss/hbeu50384313_102_21?$large$&wid=270
# Saved hbeu50384313_102_21?$large$&wid=2704
# https://images.hugoboss.com/is/image/boss/hbeu50327680_100_21?$large$&wid=270
# Saved hbeu50327680_100_21?$large$&wid=2705
# https://images.hugoboss.com/is/image/boss/hbeu50383182_410_21?$large$&wid=270
# Saved hbeu50383182_410_21?$large$&wid=2706
# https://images.hugoboss.com/is/image/boss/hbeu50328297_100_21?$large$&wid=270
# Saved hbeu50328297_100_21?$large$&wid=2707
# ...
