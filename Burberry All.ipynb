# %%
import os
import time

os.makedirs('./Burberry T-shirt/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re

URL = "https://tw.burberry.com/mens-polo-shirts-t-shirts/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)

URL = "https://tw.burberry.com/mens-shirts/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)

URL = "https://tw.burberry.com/mens-knitwear/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
        
URL = "https://tw.burberry.com/mens-sweatshirts/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry T-shirt/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://assets.burberry.com/is/image/Burberryltd/7684d1bf77bcf138587ef137def6b6e61c6ed27e.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 7684d1bf77bcf138587ef137def6b6e61c6ed27e.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/68ed30151f6f71c9fd2585baecf11e9475166dec.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 68ed30151f6f71c9fd2585baecf11e9475166dec.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/3a1715e2f0edc1b6cd4d61d056b4c05227874a0b.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 3a1715e2f0edc1b6cd4d61d056b4c05227874a0b.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/790da4353566581cdf3fb72f8d269aff86132f3c.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 790da4353566581cdf3fb72f8d269aff86132f3c.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/0b2e9414a0ad03b84c3449a01d176091c0238a65.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# ...

# %%
import os
import time

os.makedirs('./Burberry Suit/', exist_ok=True)

from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import re

URL = "https://tw.burberry.com/mens-tailoring-suits/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
i=0
for ul in img_ul:
    imgs = ul.find_all('img')
    
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry Suit/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)

URL = "https://tw.burberry.com/mens-blazers/"

headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
re = requests.get(URL, headers=headers) 
re.encoding = 'utf8'

html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('div', class_='products')
for ul in img_ul:
    imgs = ul.find_all('img')
    for img in imgs:
        url = img["src"]
        print(url)

        i = i + 1
        if(i % 2 == 0):
            continue
            
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('./Burberry Suit/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# https://assets.burberry.com/is/image/Burberryltd/68a071dcc4561615be092c9a4a26dd8169bff7a2.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 68a071dcc4561615be092c9a4a26dd8169bff7a2.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/46e5871c1b974f453aa610ed2414d5a8b1a4ac50.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 46e5871c1b974f453aa610ed2414d5a8b1a4ac50.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/a510e6375ae886c5cd3b6fc73981dcf12425d1fb.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved a510e6375ae886c5cd3b6fc73981dcf12425d1fb.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/8462b4fa06755e7a4ed09469e03018f564b9ba5e.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# Saved 8462b4fa06755e7a4ed09469e03018f564b9ba5e.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
#
# https://assets.burberry.com/is/image/Burberryltd/4e1493463fc9a626f6ac74dd78dd17bd79299342.jpg?$BBY_V2_ML_3X4$&wid=570&hei=760
# ...
